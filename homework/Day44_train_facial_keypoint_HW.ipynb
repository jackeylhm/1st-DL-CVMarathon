# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'D:\\Document\\AI\\Cupoy\\ComputerVision\\Day_042\\training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0066 - val_loss: 0.0022
#
# Epoch 00001: val_loss improved from inf to 0.00224, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00224 to 0.00189, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00189 to 0.00186, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00186
# Epoch 5/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00186 to 0.00180, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00006: val_loss improved from 0.00180 to 0.00177, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.9664e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00177 to 0.00156, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 7.3125e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00156 to 0.00139, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 6.6445e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00139 to 0.00130, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 6.0035e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00130 to 0.00118, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 5.5201e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00118 to 0.00116, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 5.1954e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00116 to 0.00109, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 4.6606e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00109 to 0.00100, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 4.4507e-04 - val_loss: 9.8535e-04
#
# Epoch 00014: val_loss improved from 0.00100 to 0.00099, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 4.0951e-04 - val_loss: 9.5611e-04
#
# Epoch 00015: val_loss improved from 0.00099 to 0.00096, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.8833e-04 - val_loss: 9.0711e-04
#
# Epoch 00016: val_loss improved from 0.00096 to 0.00091, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.7674e-04 - val_loss: 9.3272e-04
#
# Epoch 00017: val_loss did not improve from 0.00091
# Epoch 18/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.5726e-04 - val_loss: 9.1920e-04
#
# Epoch 00018: val_loss did not improve from 0.00091
# Epoch 19/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.5345e-04 - val_loss: 8.8473e-04
#
# Epoch 00019: val_loss improved from 0.00091 to 0.00088, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.2969e-04 - val_loss: 9.1607e-04
#
# Epoch 00020: val_loss did not improve from 0.00088
# Epoch 21/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.1869e-04 - val_loss: 8.6540e-04
#
# Epoch 00021: val_loss improved from 0.00088 to 0.00087, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.0818e-04 - val_loss: 8.1807e-04
#
# Epoch 00022: val_loss improved from 0.00087 to 0.00082, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 3.0582e-04 - val_loss: 8.4730e-04
#
# Epoch 00023: val_loss did not improve from 0.00082
# Epoch 24/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.9186e-04 - val_loss: 8.4220e-04
#
# Epoch 00024: val_loss did not improve from 0.00082
# Epoch 25/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.8092e-04 - val_loss: 7.8971e-04
#
# Epoch 00025: val_loss improved from 0.00082 to 0.00079, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.7374e-04 - val_loss: 8.3846e-04
#
# Epoch 00026: val_loss did not improve from 0.00079
# Epoch 27/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.6634e-04 - val_loss: 7.7700e-04
#
# Epoch 00027: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.6445e-04 - val_loss: 7.9951e-04
#
# Epoch 00028: val_loss did not improve from 0.00078
# Epoch 29/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.5748e-04 - val_loss: 8.7575e-04
#
# Epoch 00029: val_loss did not improve from 0.00078
# Epoch 30/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.5072e-04 - val_loss: 7.8331e-04
#
# Epoch 00030: val_loss did not improve from 0.00078
# Epoch 31/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.4126e-04 - val_loss: 7.7923e-04
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.4312e-04 - val_loss: 7.7675e-04
#
# Epoch 00032: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3995e-04 - val_loss: 8.3781e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.3428e-04 - val_loss: 7.7170e-04
#
# Epoch 00034: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2691e-04 - val_loss: 7.6960e-04
#
# Epoch 00035: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1975e-04 - val_loss: 7.6728e-04
#
# Epoch 00036: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.1799e-04 - val_loss: 7.8108e-04
#
# Epoch 00037: val_loss did not improve from 0.00077
# Epoch 38/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.1889e-04 - val_loss: 7.6158e-04
#
# Epoch 00038: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 2.0913e-04 - val_loss: 7.8265e-04
#
# Epoch 00039: val_loss did not improve from 0.00076
# Epoch 40/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0953e-04 - val_loss: 7.5639e-04
#
# Epoch 00040: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1931e-04 - val_loss: 7.6424e-04
#
# Epoch 00041: val_loss did not improve from 0.00076
# Epoch 42/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1165e-04 - val_loss: 7.7002e-04
#
# Epoch 00042: val_loss did not improve from 0.00076
# Epoch 43/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0799e-04 - val_loss: 7.4188e-04
#
# Epoch 00043: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 44/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0067e-04 - val_loss: 7.5925e-04
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.9494e-04 - val_loss: 7.7508e-04
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.9040e-04 - val_loss: 7.6670e-04
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8736e-04 - val_loss: 7.6312e-04
#
# Epoch 00047: val_loss did not improve from 0.00074
# Epoch 48/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8373e-04 - val_loss: 7.4282e-04
#
# Epoch 00048: val_loss did not improve from 0.00074
# Epoch 49/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8705e-04 - val_loss: 8.1517e-04
#
# Epoch 00049: val_loss did not improve from 0.00074
# Epoch 50/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.8176e-04 - val_loss: 7.1780e-04
#
# Epoch 00050: val_loss improved from 0.00074 to 0.00072, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.8056e-04 - val_loss: 7.3788e-04
#
# Epoch 00051: val_loss did not improve from 0.00072
# Epoch 52/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.8032e-04 - val_loss: 7.5146e-04
#
# Epoch 00052: val_loss did not improve from 0.00072
# Epoch 53/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.7307e-04 - val_loss: 7.4126e-04
#
# Epoch 00053: val_loss did not improve from 0.00072
# Epoch 54/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.7138e-04 - val_loss: 7.4603e-04
#
# Epoch 00054: val_loss did not improve from 0.00072
# Epoch 55/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.6925e-04 - val_loss: 7.4191e-04
#
# Epoch 00055: val_loss did not improve from 0.00072
# Epoch 56/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.6975e-04 - val_loss: 7.2226e-04
#
# Epoch 00056: val_loss did not improve from 0.00072
# Epoch 57/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.6623e-04 - val_loss: 7.5076e-04
#
# Epoch 00057: val_loss did not improve from 0.00072
# Epoch 58/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.6456e-04 - val_loss: 7.6118e-04
#
# Epoch 00058: val_loss did not improve from 0.00072
# Epoch 59/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5755e-04 - val_loss: 7.5502e-04
#
# Epoch 00059: val_loss did not improve from 0.00072
# Epoch 60/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5720e-04 - val_loss: 7.4388e-04
#
# Epoch 00060: val_loss did not improve from 0.00072
# Epoch 61/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.5582e-04 - val_loss: 7.1038e-04
#
# Epoch 00061: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 62/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.6103e-04 - val_loss: 7.5996e-04
#
# Epoch 00062: val_loss did not improve from 0.00071
# Epoch 63/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.5561e-04 - val_loss: 7.5508e-04
#
# Epoch 00063: val_loss did not improve from 0.00071
# Epoch 64/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.5600e-04 - val_loss: 8.2981e-04
#
# Epoch 00064: val_loss did not improve from 0.00071
# Epoch 65/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.5814e-04 - val_loss: 7.7135e-04
#
# Epoch 00065: val_loss did not improve from 0.00071
# Epoch 66/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4797e-04 - val_loss: 7.2139e-04
#
# Epoch 00066: val_loss did not improve from 0.00071
# Epoch 67/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4807e-04 - val_loss: 7.5408e-04
#
# Epoch 00067: val_loss did not improve from 0.00071
# Epoch 68/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4690e-04 - val_loss: 7.9552e-04
#
# Epoch 00068: val_loss did not improve from 0.00071
# Epoch 69/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.4859e-04 - val_loss: 7.2910e-04
#
# Epoch 00069: val_loss did not improve from 0.00071
# Epoch 70/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4293e-04 - val_loss: 7.3655e-04
#
# Epoch 00070: val_loss did not improve from 0.00071
# Epoch 71/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4274e-04 - val_loss: 7.6436e-04
#
# Epoch 00071: val_loss did not improve from 0.00071
# Epoch 72/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.4224e-04 - val_loss: 7.3247e-04
#
# Epoch 00072: val_loss did not improve from 0.00071
# Epoch 73/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4246e-04 - val_loss: 7.5416e-04
#
# Epoch 00073: val_loss did not improve from 0.00071
# Epoch 74/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3873e-04 - val_loss: 7.4254e-04
#
# Epoch 00074: val_loss did not improve from 0.00071
# Epoch 75/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3798e-04 - val_loss: 7.6491e-04
#
# Epoch 00075: val_loss did not improve from 0.00071
# Epoch 76/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3401e-04 - val_loss: 7.3631e-04
#
# Epoch 00076: val_loss did not improve from 0.00071
# Epoch 77/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3696e-04 - val_loss: 7.2533e-04
#
# Epoch 00077: val_loss did not improve from 0.00071
# Epoch 78/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3359e-04 - val_loss: 7.7331e-04
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3207e-04 - val_loss: 7.7008e-04
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 1.3512e-04 - val_loss: 7.4463e-04
#
# Epoch 00080: val_loss did not improve from 0.00071
# Epoch 81/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3687e-04 - val_loss: 7.8190e-04
#
# Epoch 00081: val_loss did not improve from 0.00071
# Epoch 82/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3458e-04 - val_loss: 7.3549e-04
#
# Epoch 00082: val_loss did not improve from 0.00071
# Epoch 83/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.3247e-04 - val_loss: 7.4605e-04
#
# Epoch 00083: val_loss did not improve from 0.00071
# Epoch 84/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2757e-04 - val_loss: 7.2368e-04
#
# Epoch 00084: val_loss did not improve from 0.00071
# Epoch 85/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2804e-04 - val_loss: 7.5516e-04
#
# Epoch 00085: val_loss did not improve from 0.00071
# Epoch 86/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2669e-04 - val_loss: 7.7148e-04
#
# Epoch 00086: val_loss did not improve from 0.00071
# Epoch 87/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2614e-04 - val_loss: 7.4996e-04
#
# Epoch 00087: val_loss did not improve from 0.00071
# Epoch 88/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2531e-04 - val_loss: 7.2584e-04
#
# Epoch 00088: val_loss did not improve from 0.00071
# Epoch 89/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1983e-04 - val_loss: 7.1701e-04
#
# Epoch 00089: val_loss did not improve from 0.00071
# Epoch 90/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2269e-04 - val_loss: 7.0383e-04
#
# Epoch 00090: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 91/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2244e-04 - val_loss: 7.7419e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2660e-04 - val_loss: 7.7018e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2164e-04 - val_loss: 6.8582e-04
#
# Epoch 00093: val_loss improved from 0.00070 to 0.00069, saving model to best_weights.h5
# Epoch 94/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2091e-04 - val_loss: 7.1572e-04
#
# Epoch 00094: val_loss did not improve from 0.00069
# Epoch 95/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.2019e-04 - val_loss: 7.5106e-04
#
# Epoch 00095: val_loss did not improve from 0.00069
# Epoch 96/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1738e-04 - val_loss: 7.3600e-04
#
# Epoch 00096: val_loss did not improve from 0.00069
# Epoch 97/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1803e-04 - val_loss: 7.7023e-04
#
# Epoch 00097: val_loss did not improve from 0.00069
# Epoch 98/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1595e-04 - val_loss: 7.3096e-04
#
# Epoch 00098: val_loss did not improve from 0.00069
# Epoch 99/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1398e-04 - val_loss: 7.4049e-04
#
# Epoch 00099: val_loss did not improve from 0.00069
# Epoch 100/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1287e-04 - val_loss: 7.2452e-04
#
# Epoch 00100: val_loss did not improve from 0.00069
# Epoch 101/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1257e-04 - val_loss: 7.3224e-04
#
# Epoch 00101: val_loss did not improve from 0.00069
# Epoch 102/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1287e-04 - val_loss: 7.4855e-04
#
# Epoch 00102: val_loss did not improve from 0.00069
# Epoch 103/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1126e-04 - val_loss: 7.3889e-04
#
# Epoch 00103: val_loss did not improve from 0.00069
# Epoch 104/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1152e-04 - val_loss: 7.3971e-04
#
# Epoch 00104: val_loss did not improve from 0.00069
# Epoch 105/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0800e-04 - val_loss: 7.4256e-04
#
# Epoch 00105: val_loss did not improve from 0.00069
# Epoch 106/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0695e-04 - val_loss: 7.4130e-04
#
# Epoch 00106: val_loss did not improve from 0.00069
# Epoch 107/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0581e-04 - val_loss: 7.4514e-04
#
# Epoch 00107: val_loss did not improve from 0.00069
# Epoch 108/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.1096e-04 - val_loss: 7.1126e-04
#
# Epoch 00108: val_loss did not improve from 0.00069
# Epoch 109/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0694e-04 - val_loss: 7.5646e-04
#
# Epoch 00109: val_loss did not improve from 0.00069
# Epoch 110/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0531e-04 - val_loss: 7.6557e-04
#
# Epoch 00110: val_loss did not improve from 0.00069
# Epoch 111/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0278e-04 - val_loss: 7.3577e-04
#
# Epoch 00111: val_loss did not improve from 0.00069
# Epoch 112/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0416e-04 - val_loss: 7.3993e-04
#
# Epoch 00112: val_loss did not improve from 0.00069
# Epoch 113/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0181e-04 - val_loss: 7.1961e-04
#
# Epoch 00113: val_loss did not improve from 0.00069
# Epoch 114/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0331e-04 - val_loss: 7.3343e-04
#
# Epoch 00114: val_loss did not improve from 0.00069
# Epoch 115/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0335e-04 - val_loss: 7.4105e-04
#
# Epoch 00115: val_loss did not improve from 0.00069
# Epoch 116/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0153e-04 - val_loss: 7.3624e-04
#
# Epoch 00116: val_loss did not improve from 0.00069
# Epoch 117/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 1.0121e-04 - val_loss: 7.2320e-04
#
# Epoch 00117: val_loss did not improve from 0.00069
# Epoch 118/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.9327e-05 - val_loss: 7.5292e-04
#
# Epoch 00118: val_loss did not improve from 0.00069
# Epoch 119/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.8540e-05 - val_loss: 7.4350e-04
#
# Epoch 00119: val_loss did not improve from 0.00069
# Epoch 120/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.7056e-05 - val_loss: 7.4048e-04
#
# Epoch 00120: val_loss did not improve from 0.00069
# Epoch 121/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.4132e-05 - val_loss: 7.4006e-04
#
# Epoch 00121: val_loss did not improve from 0.00069
# Epoch 122/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.4296e-05 - val_loss: 7.3305e-04
#
# Epoch 00122: val_loss did not improve from 0.00069
# Epoch 123/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.9392e-05 - val_loss: 7.1969e-04
#
# Epoch 00123: val_loss did not improve from 0.00069
# Epoch 124/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.8500e-05 - val_loss: 7.4688e-04
#
# Epoch 00124: val_loss did not improve from 0.00069
# Epoch 125/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.5813e-05 - val_loss: 7.9570e-04
#
# Epoch 00125: val_loss did not improve from 0.00069
# Epoch 126/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.5681e-05 - val_loss: 7.5102e-04
#
# Epoch 00126: val_loss did not improve from 0.00069
# Epoch 127/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.1793e-05 - val_loss: 7.2216e-04
#
# Epoch 00127: val_loss did not improve from 0.00069
# Epoch 128/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.3628e-05 - val_loss: 7.6519e-04
#
# Epoch 00128: val_loss did not improve from 0.00069
# Epoch 129/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.3231e-05 - val_loss: 7.4846e-04
#
# Epoch 00129: val_loss did not improve from 0.00069
# Epoch 130/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.4211e-05 - val_loss: 7.4260e-04
#
# Epoch 00130: val_loss did not improve from 0.00069
# Epoch 131/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.3239e-05 - val_loss: 7.0781e-04
#
# Epoch 00131: val_loss did not improve from 0.00069
# Epoch 132/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.1548e-05 - val_loss: 7.4920e-04
#
# Epoch 00132: val_loss did not improve from 0.00069
# Epoch 133/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.1860e-05 - val_loss: 7.6251e-04
#
# Epoch 00133: val_loss did not improve from 0.00069
# Epoch 134/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 9.2835e-05 - val_loss: 7.4657e-04
#
# Epoch 00134: val_loss did not improve from 0.00069
# Epoch 135/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.9685e-05 - val_loss: 7.2169e-04
#
# Epoch 00135: val_loss did not improve from 0.00069
# Epoch 136/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.8957e-05 - val_loss: 7.3473e-04
#
# Epoch 00136: val_loss did not improve from 0.00069
# Epoch 137/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.8292e-05 - val_loss: 7.6598e-04
#
# Epoch 00137: val_loss did not improve from 0.00069
# Epoch 138/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.9772e-05 - val_loss: 7.3091e-04
#
# Epoch 00138: val_loss did not improve from 0.00069
# Epoch 139/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.7974e-05 - val_loss: 7.7281e-04
#
# Epoch 00139: val_loss did not improve from 0.00069
# Epoch 140/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.8184e-05 - val_loss: 7.3999e-04
#
# Epoch 00140: val_loss did not improve from 0.00069
# Epoch 141/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.9787e-05 - val_loss: 7.7180e-04
#
# Epoch 00141: val_loss did not improve from 0.00069
# Epoch 142/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.8556e-05 - val_loss: 7.4655e-04
# Epoch 00142: val_loss did not improve from 0.00069
# Epoch 143/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.5940e-05 - val_loss: 7.6596e-04
#
# Epoch 00143: val_loss did not improve from 0.00069
# Epoch 144/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.7289e-05 - val_loss: 7.5071e-04
#
# Epoch 00144: val_loss did not improve from 0.00069
# Epoch 145/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.7487e-05 - val_loss: 7.4459e-04
#
# Epoch 00145: val_loss did not improve from 0.00069
# Epoch 146/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.2728e-05 - val_loss: 7.2871e-04
#
# Epoch 00146: val_loss did not improve from 0.00069
# Epoch 147/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.4916e-05 - val_loss: 7.7425e-04
#
# Epoch 00147: val_loss did not improve from 0.00069
# Epoch 148/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.4097e-05 - val_loss: 7.3772e-04
#
# Epoch 00148: val_loss did not improve from 0.00069
# Epoch 149/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.5186e-05 - val_loss: 7.3459e-04
#
# Epoch 00149: val_loss did not improve from 0.00069
# Epoch 150/150
# 1712/1712 [==============================] - 5s 3ms/step - loss: 8.3305e-05 - val_loss: 7.3734e-04
#
# Epoch 00150: val_loss did not improve from 0.00069

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'D:\\Document\\AI\\Cupoy\\ComputerVision\\Day_042\\test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。
#
# 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 0.0048 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00189, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00002: val_loss improved from 0.00189 to 0.00184, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00184 to 0.00180, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.0675e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00180 to 0.00156, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 6.9148e-04 - val_loss: 0.0012
#
# Epoch 00005: val_loss improved from 0.00156 to 0.00116, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 5.6645e-04 - val_loss: 0.0010
#
# Epoch 00006: val_loss improved from 0.00116 to 0.00105, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 4.9299e-04 - val_loss: 9.3249e-04
#
# Epoch 00007: val_loss improved from 0.00105 to 0.00093, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 4.4656e-04 - val_loss: 8.7981e-04
#
# Epoch 00008: val_loss improved from 0.00093 to 0.00088, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 4.1563e-04 - val_loss: 8.9043e-04
#
# Epoch 00009: val_loss did not improve from 0.00088
# Epoch 10/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 3.8166e-04 - val_loss: 8.2391e-04
#
# Epoch 00010: val_loss improved from 0.00088 to 0.00082, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 3.5443e-04 - val_loss: 7.5964e-04
#
# Epoch 00011: val_loss improved from 0.00082 to 0.00076, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 3.4006e-04 - val_loss: 7.3700e-04
#
# Epoch 00012: val_loss improved from 0.00076 to 0.00074, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.2980e-04 - val_loss: 7.4087e-04
#
# Epoch 00013: val_loss did not improve from 0.00074
# Epoch 14/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.1488e-04 - val_loss: 7.0286e-04
#
# Epoch 00014: val_loss improved from 0.00074 to 0.00070, saving model to best_weights_augment.h5
# Epoch 15/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.9675e-04 - val_loss: 7.0757e-04
#
# Epoch 00015: val_loss did not improve from 0.00070
# Epoch 16/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.8740e-04 - val_loss: 6.8343e-04
#
# Epoch 00016: val_loss improved from 0.00070 to 0.00068, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.7852e-04 - val_loss: 6.8241e-04
#
# Epoch 00017: val_loss improved from 0.00068 to 0.00068, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.6779e-04 - val_loss: 6.5693e-04
#
# Epoch 00018: val_loss improved from 0.00068 to 0.00066, saving model to best_weights_augment.h5
# Epoch 19/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.6883e-04 - val_loss: 6.8753e-04
#
# Epoch 00019: val_loss did not improve from 0.00066
# Epoch 20/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.5621e-04 - val_loss: 6.5777e-04
#
# Epoch 00020: val_loss did not improve from 0.00066
# Epoch 21/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.4792e-04 - val_loss: 6.3238e-04
#
# Epoch 00021: val_loss improved from 0.00066 to 0.00063, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.4075e-04 - val_loss: 6.5904e-04
#
# Epoch 00022: val_loss did not improve from 0.00063
# Epoch 23/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.3054e-04 - val_loss: 6.2709e-04
#
# Epoch 00023: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 24/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.3068e-04 - val_loss: 6.0700e-04
#
# Epoch 00024: val_loss improved from 0.00063 to 0.00061, saving model to best_weights_augment.h5
# Epoch 25/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.2740e-04 - val_loss: 6.0742e-04
#
# Epoch 00025: val_loss did not improve from 0.00061
# Epoch 26/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.1971e-04 - val_loss: 6.2703e-04
#
# Epoch 00026: val_loss did not improve from 0.00061
# Epoch 27/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.1787e-04 - val_loss: 6.3269e-04
#
# Epoch 00027: val_loss did not improve from 0.00061
# Epoch 28/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.0888e-04 - val_loss: 6.0098e-04
#
# Epoch 00028: val_loss improved from 0.00061 to 0.00060, saving model to best_weights_augment.h5
# Epoch 29/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.0373e-04 - val_loss: 6.7269e-04
#
# Epoch 00029: val_loss did not improve from 0.00060
# Epoch 30/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 2.0363e-04 - val_loss: 6.1747e-04
#
# Epoch 00030: val_loss did not improve from 0.00060
# Epoch 31/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.9563e-04 - val_loss: 6.3994e-04
#
# Epoch 00031: val_loss did not improve from 0.00060
# Epoch 32/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.9502e-04 - val_loss: 6.0002e-04
#
# Epoch 00032: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 33/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.9256e-04 - val_loss: 6.0090e-04
#
# Epoch 00033: val_loss did not improve from 0.00060
# Epoch 34/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.8468e-04 - val_loss: 6.1289e-04
#
# Epoch 00034: val_loss did not improve from 0.00060
# Epoch 35/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.7906e-04 - val_loss: 6.1073e-04
#
# Epoch 00035: val_loss did not improve from 0.00060
# Epoch 36/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.8231e-04 - val_loss: 5.9804e-04
#
# Epoch 00036: val_loss improved from 0.00060 to 0.00060, saving model to best_weights_augment.h5
# Epoch 37/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.7974e-04 - val_loss: 5.8457e-04
#
# Epoch 00037: val_loss improved from 0.00060 to 0.00058, saving model to best_weights_augment.h5
# Epoch 38/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.7411e-04 - val_loss: 5.9839e-04
#
# Epoch 00038: val_loss did not improve from 0.00058
# Epoch 39/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.7462e-04 - val_loss: 6.1792e-04
#
# Epoch 00039: val_loss did not improve from 0.00058
# Epoch 40/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.7344e-04 - val_loss: 5.9611e-04
#
# Epoch 00040: val_loss did not improve from 0.00058
# Epoch 41/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.6584e-04 - val_loss: 5.9517e-04
#
# Epoch 00041: val_loss did not improve from 0.00058
# Epoch 42/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.6447e-04 - val_loss: 5.9481e-04
#
# Epoch 00042: val_loss did not improve from 0.00058
# Epoch 43/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.6162e-04 - val_loss: 5.8690e-04
#
# Epoch 00043: val_loss did not improve from 0.00058
# Epoch 44/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.5571e-04 - val_loss: 5.6320e-04
# Epoch 00044: val_loss improved from 0.00058 to 0.00056, saving model to best_weights_augment.h5
# Epoch 45/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5748e-04 - val_loss: 6.0400e-04
#
# Epoch 00045: val_loss did not improve from 0.00056
# Epoch 46/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.5538e-04 - val_loss: 5.7177e-04
#
# Epoch 00046: val_loss did not improve from 0.00056
# Epoch 47/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 1.5473e-04 - val_loss: 5.8728e-04
#
# Epoch 00047: val_loss did not improve from 0.00056
# Epoch 48/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 1.4945e-04 - val_loss: 6.6895e-04
#
# Epoch 00048: val_loss did not improve from 0.00056
# Epoch 49/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.4892e-04 - val_loss: 5.9480e-04
#
# Epoch 00049: val_loss did not improve from 0.00056
# Epoch 50/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.4773e-04 - val_loss: 6.0347e-04
#
# Epoch 00050: val_loss did not improve from 0.00056
# Epoch 51/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.4484e-04 - val_loss: 6.0309e-04
#
# Epoch 00051: val_loss did not improve from 0.00056
# Epoch 52/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4715e-04 - val_loss: 6.5626e-04
#
# Epoch 00052: val_loss did not improve from 0.00056
# Epoch 53/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.4130e-04 - val_loss: 5.9026e-04
#
# Epoch 00053: val_loss did not improve from 0.00056
# Epoch 54/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.4277e-04 - val_loss: 5.8419e-04
#
# Epoch 00054: val_loss did not improve from 0.00056
# Epoch 55/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.3850e-04 - val_loss: 5.8452e-04
#
# Epoch 00055: val_loss did not improve from 0.00056
# Epoch 56/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.3514e-04 - val_loss: 6.3338e-04
#
# Epoch 00056: val_loss did not improve from 0.00056
# Epoch 57/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.3239e-04 - val_loss: 6.1753e-04
#
# Epoch 00057: val_loss did not improve from 0.00056
# Epoch 58/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.3273e-04 - val_loss: 5.8529e-04
#
# Epoch 00058: val_loss did not improve from 0.00056
# Epoch 59/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2948e-04 - val_loss: 6.3898e-04
#
# Epoch 00059: val_loss did not improve from 0.00056
# Epoch 60/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.2744e-04 - val_loss: 5.7021e-04
#
# Epoch 00060: val_loss did not improve from 0.00056
# Epoch 61/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.3022e-04 - val_loss: 5.8863e-04
#
# Epoch 00061: val_loss did not improve from 0.00056
# Epoch 62/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.2948e-04 - val_loss: 5.8603e-04
#
# Epoch 00062: val_loss did not improve from 0.00056
# Epoch 63/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.3045e-04 - val_loss: 6.0359e-04
#
# Epoch 00063: val_loss did not improve from 0.00056
# Epoch 64/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.2420e-04 - val_loss: 5.8920e-04
#
# Epoch 00064: val_loss did not improve from 0.00056
# Epoch 65/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.2426e-04 - val_loss: 5.8099e-04
#
# Epoch 00065: val_loss did not improve from 0.00056
# Epoch 66/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.2347e-04 - val_loss: 6.1758e-04
#
# Epoch 00066: val_loss did not improve from 0.00056
# Epoch 67/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.2094e-04 - val_loss: 5.8566e-04
#
# Epoch 00067: val_loss did not improve from 0.00056
# Epoch 68/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2036e-04 - val_loss: 5.7458e-04
#
# Epoch 00068: val_loss did not improve from 0.00056
# Epoch 69/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1955e-04 - val_loss: 6.2267e-04
#
# Epoch 00069: val_loss did not improve from 0.00056
# Epoch 70/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1727e-04 - val_loss: 5.7329e-04
#
# Epoch 00070: val_loss did not improve from 0.00056
# Epoch 71/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1621e-04 - val_loss: 5.8552e-04
#
# Epoch 00071: val_loss did not improve from 0.00056
# Epoch 72/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1678e-04 - val_loss: 6.0868e-04
#
# Epoch 00072: val_loss did not improve from 0.00056
# Epoch 73/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1299e-04 - val_loss: 5.9114e-04
#
# Epoch 00073: val_loss did not improve from 0.00056
# Epoch 74/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1095e-04 - val_loss: 5.8862e-04
#
# Epoch 00074: val_loss did not improve from 0.00056
# Epoch 75/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1504e-04 - val_loss: 5.8883e-04
#
# Epoch 00075: val_loss did not improve from 0.00056
# Epoch 76/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1095e-04 - val_loss: 6.1481e-04
#
# Epoch 00076: val_loss did not improve from 0.00056
# Epoch 77/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1009e-04 - val_loss: 6.2484e-04
#
# Epoch 00077: val_loss did not improve from 0.00056
# Epoch 78/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1057e-04 - val_loss: 5.8916e-04
#
# Epoch 00078: val_loss did not improve from 0.00056
# Epoch 79/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.1134e-04 - val_loss: 6.2693e-04
#
# Epoch 00079: val_loss did not improve from 0.00056
# Epoch 80/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0952e-04 - val_loss: 5.8507e-04
#
# Epoch 00080: val_loss did not improve from 0.00056
# Epoch 81/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0594e-04 - val_loss: 5.8667e-04
#
# Epoch 00081: val_loss did not improve from 0.00056
# Epoch 82/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0620e-04 - val_loss: 5.8409e-04
#
# Epoch 00082: val_loss did not improve from 0.00056
# Epoch 83/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0652e-04 - val_loss: 5.9162e-04
#
# Epoch 00083: val_loss did not improve from 0.00056
# Epoch 84/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0566e-04 - val_loss: 6.0180e-04
#
# Epoch 00084: val_loss did not improve from 0.00056
# Epoch 85/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0474e-04 - val_loss: 6.2732e-04
#
# Epoch 00085: val_loss did not improve from 0.00056
# Epoch 86/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0480e-04 - val_loss: 6.0546e-04
#
# Epoch 00086: val_loss did not improve from 0.00056
# Epoch 87/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0916e-04 - val_loss: 5.9581e-04
#
# Epoch 00087: val_loss did not improve from 0.00056
# Epoch 88/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0688e-04 - val_loss: 5.9518e-04
#
# Epoch 00088: val_loss did not improve from 0.00056
# Epoch 89/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0476e-04 - val_loss: 6.0301e-04
#
# Epoch 00089: val_loss did not improve from 0.00056
# Epoch 90/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0340e-04 - val_loss: 5.7726e-04
#
# Epoch 00090: val_loss did not improve from 0.00056
# Epoch 91/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.8725e-05 - val_loss: 5.8189e-04
#
# Epoch 00091: val_loss did not improve from 0.00056
# Epoch 92/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.8815e-05 - val_loss: 5.8439e-04
#
# Epoch 00092: val_loss did not improve from 0.00056
# Epoch 93/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.6963e-05 - val_loss: 5.8984e-04
#
# Epoch 00093: val_loss did not improve from 0.00056
# Epoch 94/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.8409e-05 - val_loss: 6.3402e-04
#
# Epoch 00094: val_loss did not improve from 0.00056
# Epoch 95/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0123e-04 - val_loss: 6.0177e-04
#
# Epoch 00095: val_loss did not improve from 0.00056
# Epoch 96/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 1.0043e-04 - val_loss: 5.8688e-04
#
# Epoch 00096: val_loss did not improve from 0.00056
# Epoch 97/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.7235e-05 - val_loss: 6.0334e-04
#
# Epoch 00097: val_loss did not improve from 0.00056
# Epoch 98/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.5890e-05 - val_loss: 5.9582e-04
#
# Epoch 00098: val_loss did not improve from 0.00056
# Epoch 99/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.5335e-05 - val_loss: 5.9823e-04
#
# Epoch 00099: val_loss did not improve from 0.00056
# Epoch 100/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 9.6710e-05 - val_loss: 6.0716e-04
#
# Epoch 00100: val_loss did not improve from 0.00056
# Epoch 101/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.5255e-05 - val_loss: 5.9127e-04
#
# Epoch 00101: val_loss did not improve from 0.00056
# Epoch 102/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.5718e-05 - val_loss: 5.8465e-04
#
# Epoch 00102: val_loss did not improve from 0.00056
# Epoch 103/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.2710e-05 - val_loss: 6.2486e-04
#
# Epoch 00103: val_loss did not improve from 0.00056
# Epoch 104/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.4816e-05 - val_loss: 5.9289e-04
#
# Epoch 00104: val_loss did not improve from 0.00056
# Epoch 105/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.4799e-05 - val_loss: 5.9816e-04
#
# Epoch 00105: val_loss did not improve from 0.00056
# Epoch 106/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.5052e-05 - val_loss: 5.7960e-04
#
# Epoch 00106: val_loss did not improve from 0.00056
# Epoch 107/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 9.5780e-05 - val_loss: 6.0473e-04
#
# Epoch 00107: val_loss did not improve from 0.00056
# Epoch 108/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 9.3266e-05 - val_loss: 6.0558e-04
#
# Epoch 00108: val_loss did not improve from 0.00056
# Epoch 109/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.8948e-05 - val_loss: 5.9035e-04
#
# Epoch 00109: val_loss did not improve from 0.00056
# Epoch 110/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.1247e-05 - val_loss: 5.9410e-04
#
# Epoch 00110: val_loss did not improve from 0.00056
# Epoch 111/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 9.1555e-05 - val_loss: 6.1159e-04
#
# Epoch 00111: val_loss did not improve from 0.00056
# Epoch 112/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.9018e-05 - val_loss: 6.0503e-04
#
# Epoch 00112: val_loss did not improve from 0.00056
# Epoch 113/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.9405e-05 - val_loss: 6.0270e-04
#
# Epoch 00113: val_loss did not improve from 0.00056
# Epoch 114/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.8719e-05 - val_loss: 6.0012e-04
#
# Epoch 00114: val_loss did not improve from 0.00056
# Epoch 115/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.9578e-05 - val_loss: 5.8712e-04
#
# Epoch 00115: val_loss did not improve from 0.00056
# Epoch 116/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.0541e-05 - val_loss: 6.1217e-04
#
# Epoch 00116: val_loss did not improve from 0.00056
# Epoch 117/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.9902e-05 - val_loss: 5.8980e-04
#
# Epoch 00117: val_loss did not improve from 0.00056
# Epoch 118/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 9.0182e-05 - val_loss: 6.1596e-04
#
# Epoch 00118: val_loss did not improve from 0.00056
# Epoch 119/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.6338e-05 - val_loss: 6.0870e-04
#
# Epoch 00119: val_loss did not improve from 0.00056
# Epoch 120/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.5289e-05 - val_loss: 5.9994e-04
#
# Epoch 00120: val_loss did not improve from 0.00056
# Epoch 121/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.7609e-05 - val_loss: 6.1033e-04
#
# Epoch 00121: val_loss did not improve from 0.00056
# Epoch 122/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.7354e-05 - val_loss: 5.8951e-04
#
# Epoch 00122: val_loss did not improve from 0.00056
# Epoch 123/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.9753e-05 - val_loss: 5.9103e-04
#
# Epoch 00123: val_loss did not improve from 0.00056
# Epoch 124/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.6953e-05 - val_loss: 6.2366e-04
#
# Epoch 00124: val_loss did not improve from 0.00056
# Epoch 125/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.6756e-05 - val_loss: 6.0597e-04
#
# Epoch 00125: val_loss did not improve from 0.00056
# Epoch 126/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.5616e-05 - val_loss: 6.1400e-04
#
# Epoch 00126: val_loss did not improve from 0.00056
# Epoch 127/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.6123e-05 - val_loss: 5.8159e-04
#
# Epoch 00127: val_loss did not improve from 0.00056
# Epoch 128/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.6218e-05 - val_loss: 6.0548e-04
#
# Epoch 00128: val_loss did not improve from 0.00056
# Epoch 129/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.5948e-05 - val_loss: 5.9931e-04
#
# Epoch 00129: val_loss did not improve from 0.00056
# Epoch 130/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.3071e-05 - val_loss: 6.1136e-04
#
# Epoch 00130: val_loss did not improve from 0.00056
# Epoch 131/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.4813e-05 - val_loss: 6.1430e-04
#
# Epoch 00131: val_loss did not improve from 0.00056
# Epoch 132/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.4087e-05 - val_loss: 5.9087e-04
#
# Epoch 00132: val_loss did not improve from 0.00056
# Epoch 133/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.4720e-05 - val_loss: 5.8880e-04
#
# Epoch 00133: val_loss did not improve from 0.00056
# Epoch 134/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.4894e-05 - val_loss: 5.9386e-04
#
# Epoch 00134: val_loss did not improve from 0.00056
# Epoch 135/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.7152e-05 - val_loss: 6.1003e-04
#
# Epoch 00135: val_loss did not improve from 0.00056
# Epoch 136/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.3899e-05 - val_loss: 5.8957e-04
#
# Epoch 00136: val_loss did not improve from 0.00056
# Epoch 137/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.6124e-05 - val_loss: 6.1252e-04
#
# Epoch 00137: val_loss did not improve from 0.00056
# Epoch 138/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.4865e-05 - val_loss: 6.0438e-04
#
# Epoch 00138: val_loss did not improve from 0.00056
# Epoch 139/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.3604e-05 - val_loss: 5.8612e-04
#
# Epoch 00139: val_loss did not improve from 0.00056
# Epoch 140/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.2525e-05 - val_loss: 5.9965e-04
#
# Epoch 00140: val_loss did not improve from 0.00056
# Epoch 141/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.3238e-05 - val_loss: 6.1135e-04
#
# Epoch 00141: val_loss did not improve from 0.00056
# Epoch 142/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.4889e-05 - val_loss: 6.2500e-04
#
# Epoch 00142: val_loss did not improve from 0.00056
# Epoch 143/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.3383e-05 - val_loss: 6.0974e-04
# Epoch 00143: val_loss did not improve from 0.00056
# Epoch 144/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.3311e-05 - val_loss: 6.1148e-04
#
# Epoch 00144: val_loss did not improve from 0.00056
# Epoch 145/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.0404e-05 - val_loss: 5.8649e-04
#
# Epoch 00145: val_loss did not improve from 0.00056
# Epoch 146/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.2084e-05 - val_loss: 5.9987e-04
#
# Epoch 00146: val_loss did not improve from 0.00056
# Epoch 147/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.2660e-05 - val_loss: 6.1489e-04
#
# Epoch 00147: val_loss did not improve from 0.00056
# Epoch 148/150
# 3424/3424 [==============================] - 10s 3ms/step - loss: 8.2224e-05 - val_loss: 5.8674e-04
#
# Epoch 00148: val_loss did not improve from 0.00056
# Epoch 149/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.2352e-05 - val_loss: 6.1670e-04
#
# Epoch 00149: val_loss did not improve from 0.00056
# Epoch 150/150
# 3424/3424 [==============================] - 9s 3ms/step - loss: 8.1173e-05 - val_loss: 6.1295e-04
#
# Epoch 00150: val_loss did not improve from 0.00056

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
